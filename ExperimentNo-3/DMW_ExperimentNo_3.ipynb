# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi-Thorat/DMW/blob/main/ExperimentNo-3/DMW_ExperimentNo_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DMW Experiment No. : 02
#
# Sakshi Thorat-B.E(B-17)
#
# Apply a-priori algorithm to find frequently occurring items from given data and generate strong association rules using support and confidence thresholds. For Example: Market Basket Analysis .

# %%
import pandas as pd
#importing dataset
df = pd.read_csv('Market_Basket.csv',header=None)
df.head()
# Out:
#               0          1           2   ...               17       18         19
# 0         shrimp    almonds     avocado  ...  frozen smoothie  spinach  olive oil
# 1        burgers  meatballs        eggs  ...              NaN      NaN        NaN
# 2        chutney        NaN         NaN  ...              NaN      NaN        NaN
# 3         turkey    avocado         NaN  ...              NaN      NaN        NaN
# 4  mineral water       milk  energy bar  ...              NaN      NaN        NaN
#
# [5 rows x 20 columns]

# %%
#convert data in list format
transactions = []
for i in range(0,len(df)):
    transactions.append([str(df.values[i,j]) for j in range(0,20) if str(df.values[i,j])!='nan'])

# %%
from mlxtend.preprocessing import TransactionEncoder
Te = TransactionEncoder()
Te_array = Te.fit(transactions).transform(transactions)
Te_df = pd.DataFrame(array, columns = Te.columns_)
Te_df
# Out:
#        asparagus  almonds  antioxydant juice  ...   yams  yogurt cake  zucchini
# 0          False     True               True  ...   True        False     False
# 1          False    False              False  ...  False        False     False
# 2          False    False              False  ...  False        False     False
# 3          False    False              False  ...  False        False     False
# 4          False    False              False  ...  False        False     False
# ...          ...      ...                ...  ...    ...          ...       ...
# 7496       False    False              False  ...  False        False     False
# 7497       False    False              False  ...  False        False     False
# 7498       False    False              False  ...  False        False     False
# 7499       False    False              False  ...  False        False     False
# 7500       False    False              False  ...  False         True     False
#
# ...

# %%
from mlxtend.frequent_patterns import apriori 
#getting frequent itemset
frequent_itemsets=apriori(Te_df,min_support=0.05,use_colnames=True)
frequent_itemsets
# Out:
#      support                    itemsets
# 0   0.087188                   (burgers)
# 1   0.081056                      (cake)
# 2   0.059992                   (chicken)
# 3   0.163845                 (chocolate)
# 4   0.080389                   (cookies)
# 5   0.051060               (cooking oil)
# 6   0.179709                      (eggs)
# 7   0.079323                  (escalope)
# 8   0.170911              (french fries)
# 9   0.063325           (frozen smoothie)
# 10  0.095321         (frozen vegetables)
# 11  0.052393             (grated cheese)
# 12  0.132116                 (green tea)
# 13  0.098254               (ground beef)
# 14  0.076523            (low fat yogurt)
# 15  0.129583                      (milk)
# 16  0.238368             (mineral water)
# 17  0.065858                 (olive oil)
# 18  0.095054                  (pancakes)
# 19  0.071457                    (shrimp)
# 20  0.050527                      (soup)
# 21  0.174110                 (spaghetti)
# ...

# %% [markdown]
# Association Rule

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(a_rules, metric = 'confidence', min_threshold = 0.1)
rules
# Out:
#        antecedents      consequents  ...  leverage  conviction
# 0      (chocolate)  (mineral water)  ...  0.013604    1.122357
# 1  (mineral water)      (chocolate)  ...  0.013604    1.073256
# 2           (eggs)  (mineral water)  ...  0.008090    1.062815
# 3  (mineral water)           (eggs)  ...  0.008090    1.043158
# 4    (ground beef)  (mineral water)  ...  0.017507    1.305401
# 5  (mineral water)    (ground beef)  ...  0.017507    1.088672
# 6           (milk)  (mineral water)  ...  0.017105    1.209650
# 7  (mineral water)           (milk)  ...  0.017105    1.089850
# 8      (spaghetti)  (mineral water)  ...  0.018223    1.159314
# 9  (mineral water)      (spaghetti)  ...  0.018223    1.102008
#
# [10 rows x 9 columns]

# %%
rules1=rules[['antecedents','consequents','support','confidence','lift']]
rules
# Out:
#        antecedents      consequents  ...  leverage  conviction
# 0      (chocolate)  (mineral water)  ...  0.013604    1.122357
# 1  (mineral water)      (chocolate)  ...  0.013604    1.073256
# 2           (eggs)  (mineral water)  ...  0.008090    1.062815
# 3  (mineral water)           (eggs)  ...  0.008090    1.043158
# 4    (ground beef)  (mineral water)  ...  0.017507    1.305401
# 5  (mineral water)    (ground beef)  ...  0.017507    1.088672
# 6           (milk)  (mineral water)  ...  0.017105    1.209650
# 7  (mineral water)           (milk)  ...  0.017105    1.089850
# 8      (spaghetti)  (mineral water)  ...  0.018223    1.159314
# 9  (mineral water)      (spaghetti)  ...  0.018223    1.102008
#
# [10 rows x 9 columns]
